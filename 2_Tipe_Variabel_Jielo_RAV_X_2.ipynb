# %% [markdown]
# <a href="https://colab.research.google.com/github/jielloveron/KKA-XSemester-1-Jielo_R.A.V/blob/main/2_Tipe_Variabel_Jielo_RAV_X_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Jielo Robbi Ariente Veron
#
# Kelas : X-2
#
# No Absen : 14

# %% [markdown]
# **Konsep Dasar Variabel**

# %%
print("jielloveron.2025@gmail.com")
print("jielloveron.2025@gmail.com")
print("jielloveron.2025@gmail.com")
# Out:
# jielloveron.2025@gmail.com
# jielloveron.2025@gmail.com
# jielloveron.2025@gmail.com

# %%
email_user = "jielloveron.2025@gmail.com"
print (email_user)
print (email_user)
print (email_user)
# Out:
# jielloveron.2025@gmail.com
# jielloveron.2025@gmail.com
# jielloveron.2025@gmail.com

# %% [markdown]
# **Peraturan Penulisan Variabel**

# %%
#Hanya boleh menggunakan huruf,angka,dan underscore
harga telur = 15000
print (harga telur)
# Out:
#   File "/tmp/ipython-input-47184723.py", line 2
#     harga telur = 15000
#           ^
# SyntaxError: invalid syntax

# %%
hargatelur = 15000
print(hargatelur)

# %%
#Tidak boleh di awali oleh angka
1_nama_siswa = "Ahmad Dhani"

print (1_nama_siswa)
# Out:
#   File "/tmp/ipython-input-847134114.py", line 2
#     1_nama_siswa = "Ahmad Dhani"
#      ^
# SyntaxError: invalid decimal literal

# %%
#Tidak boleh menggunakan kata kunci pyton
if = "handayani"

print(if)
# Out:
#   File "/tmp/ipython-input-1102297933.py", line 2
#     if = "handayani"
#        ^
# SyntaxError: invalid syntax

# %%
IF = "handayani"

print(IF)
# Out:
# handayani

# %%
print = "Noor"

print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4169316329.py in <cell line: 0>()
#       1 print = "Noor"
#       2
# ----> 3 print(print)
#
# TypeError: 'str' object is not callable

# %%
Print = "Noor"

print (Print)
# Out:
# Noor

# %%
#sensitif terhadap penulisan kapital
USIA =17
print (Usia)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-423392091.py in <cell line: 0>()
#       1 #sensitif terhadap penulisan kapital
#       2 USIA =17
# ----> 3 print (Usia)
#
# NameError: name 'Usia' is not defined

# %%
print (USIA)
# Out:
# 17

# %%
_ = "Fazel wardana"

# %%
_ = "Lia wati"

# %%
print(_)
# Out:
# Lia wati

# %% [markdown]
# **Assignment**

# %%
#Single Assignment

bb_fazel = 55
bb_dani = 60

print(bb_dani)
print(bb_fazel)
# Out:
# 60
# 55

# %%
#Multiple Assignment

bb_fazel, bb_dani = 55,60

print(bb_dani)
print(bb_fazel)
# Out:
# 60
# 55

# %%
bb_fazel, bb_dani 55,60,70

print(bb_dani)
print(bb_fazel)
# Out:
#   File "/tmp/ipython-input-2010369218.py", line 1
#     bb_fazel, bb_dani 55,60,70
#                       ^
# SyntaxError: invalid syntax

# %%
nama_siswa_1 , nama_siswa_2 = "deni" , "doni"

print(nama_siswa_1)
print(nama_siswa_2)
# Out:
# deni
# doni

# %%
bb_fazel , bb_dani , bb_adli = 55,60

print(bb_dani)
print(bb_fazel)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3735590142.py in <cell line: 0>()
# ----> 1 bb_fazel , bb_dani , bb_adli = 55,60
#       2
#       3 print(bb_dani)
#       4 print(bb_fazel)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
#chain assignment

bb_hasbi = bb_dani = 60

print(bb_hasbi)
print(bb_dani)
# Out:
# 60
# 60

# %% [markdown]
# **Cara Penulisan Operator pada Python**

# %%
#Tanpa Variabel

print(9+6)
# Out:
# 15

# %%
print("shinta")
# Out:
# shinta

# %%
print("9+6")
# Out:
# 9+6

# %%
#Operand Disimpan ke Variabel

jumlah_hp_habibi = 10
jumlah_hp_syauqi = 6

print(jumlah_hp_habibi + jumlah_hp_syauqi)
# Out:
# 16

# %%
#Hasil Operasi disimpan ke Variabel

total_hp = 10 + 6

print(total_hp)
# Out:
# 16

# %%
#Operand dan Hasil Operasi disimpan ke Variabel

jumlah_hp_habibi = 10
jumlah_hp_syauqi = 6

total_hp = jumlah_hp_habibi + jumlah_hp_syauqi

print(total_hp)
# Out:
# 16

# %% [markdown]
# **Latihan soal coding assignment**

# %%
nama_siswa = "andi"
print(nama_siswa)
# Out:
# andi

# %% [markdown]
# **JENIS JENIS TIPE VARIABEL**

# %%
a = "faris"
print (a)
type (a)
# Out:
# faris
# str

# %%
b = 9.9
print(b)
type(b)

# %%
c = 0
print(c)
type(c)
# Out:
# 0
# int

# %%
d = true
print(d)
type(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3721722550.py in <cell line: 0>()
# ----> 1 d = true
#       2 print(d)
#       3 type(d)
#
# NameError: name 'true' is not defined

# %%
d = True
print(d)
type(d)
# Out:
# True
# bool

# %%
f = "false"
print(f)
type(f)
# Out:
# false
# str

# %%
g = 9,2
print(g)
type(g)
# Out:
# (9, 2)
# tuple

# %%
type("rendra")
# Out:
# str

# %%
type(-9.1)
# Out:
# float

# %% [markdown]
# **MENGUBAH** **BENTUK** **VARIABEL**

# %%
a = 5
print(a)
type(a)
# Out:
# 5
# int

# %%
a = float (a)
print(a)
type(a)
# Out:
# 5.0
# float

# %%
b = bool(2)
print(b)
type(b)
# Out:
# True
# bool

# %% [markdown]
# **OPERATOR PERBANDINGAN**

# %%
print(6 >= 6 )
# Out:
# True

# %%
print(8 == 9)
# Out:
# False

# %%
print(8 != 9)
# Out:
# True

# %%
print(8 < 20)
# Out:
# True

# %%
print(8 > 10)
# Out:
# False

# %%
print(5 == 5)
# Out:
# True

# %%
print( 3 < 5)
# Out:
# True

# %% [markdown]
# **OPERATOR LOGIKA**

# %%
print(not(5 <= 5))
# Out:
# False

# %%
print(8 > 7 and 6< 5)
# Out:
# False

# %%
print(7 <= 1 or 2 != 2)
# Out:
# False

# %%
print(not(0 == 1 and 1 != 2))
# Out:
# True

# %%
print(not( 5 < 10 or 5 <= 10))
# Out:
# False

# %% [markdown]
# <a href="https://colab.research.google.com/github/jielloveron/KKA-XSemester-1-Jielo_R.A.V/blob/main/3_Aplikasi_sederhana_Jielo_X_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Nama: Jielo Robbi A.V**
# **Kelas : X-2**
# **Nomer Absen : 14**

# %%
panjang = int(input("masukkan panjang dari balok (cm) :  "))
lebar   = int(input("masukkan lebar dari balok (cm) :  "))
tinggi  = int(input("masukkan tinggi dari balok(cm) :  "))

volume = panjang * lebar * tinggi

print(f"\nvolume dari balok yaitu {volume} cm^3")
# Out:
# masukkan panjang dari balok (cm) :  7
# masukkan lebar dari balok (cm) :  5
# masukkan tinggi dari balok(cm) :  10
#
# volume dari balok yaitu 350 cm^3

# %%
panjang = int(input("masukkan panjang dari balok (cm) :  "))
lebar   = int(input("masukkan lebar dari balok (cm) :  "))
tinggi  = int(input("masukkan tinggi dari balok(cm) :  "))

luas = 2 * (panjang * lebar + panjang * tinggi + lebar * tinggi)

print(f"\nluas dari balok yaitu {luas} cm^3")
# Out:
# masukkan panjang dari balok (cm) :  7
# masukkan lebar dari balok (cm) :  5
# masukkan tinggi dari balok(cm) :  10
#
# luas dari balok yaitu 310 cm^3

# %%
panjang = int(input("masukkan panjang dari persegi panjang (cm) : "))
lebar = int(input("masukkan lebar dari persegi panjang (cm) :  "))

luas = panjang * lebar

print(f"\nLuas dari persegi panjang yaitu {luas} cm^2")
# Out:
# masukkan panjang dari persegi panjang (cm) : 5
# masukkan lebar dari persegi panjang (cm) :  4
#
# Luas dari persegi panjang yaitu 20 cm^2

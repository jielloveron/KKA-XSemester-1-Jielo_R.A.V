# %% [markdown]
# <a href="https://colab.research.google.com/github/jielloveron/KKA-XSemester-1-Jielo_R.A.V/blob/main/1_Fungsi_Print_Jielo_X_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# nama:jielo robbi ariente veron
#
# kelas:X.2
#
# nomor absen:14

# %%
print("halo word")
# Out:
# halo word

# %%
print ("jielo robbi ariente veron")
# Out:
# jielo robbi ariente veron

# %% [markdown]
# menambahkan nilai variabel

# %%
nilai_KKA = 100


print(nilai_KKA)
# Out:
# 100

# %%
nama = "jielo robbi ariente veron"

print(nama)
# Out:
# jielo robbi ariente veron

# %%
usia = 14

print (usia)
# Out:
# 14

# %% [markdown]
# menampilkan text bebas dan  nilai variabel

# %%
print("nilai KKA saya adalah", nilai_KKA,"A+")
# Out:
# nilai KKA saya adalah 100 A+

# %%
print("perkenalkan nama saya",nama)
# Out:
# perkenalkan nama saya jielo robbi ariente veron

# %%
print("perkenalkan nama saya, " + nama + ".")
# Out:
# perkenalkan nama saya, jielo robbi ariente veron.

# %%
print("nilai_KKA saya adalah " + str(nilai_KKA) + "A+.")
# Out:
# nilai_KKA saya adalah 100A+.

# %%
print(f"perkenalkan nama saya {nama}.")
# Out:
# perkenalkan nama saya jielo robbi ariente veron.

# %%
print(f"nilai KKA saya adalah {nilai_KKA} A+")
# Out:
# nilai KKA saya adalah 100 A+

# %% [markdown]
# Escape Character

# %%
print("nama : jielo robbi ariente veron\nkelas :x.2\nno.absen :14")
# Out:
# nama : jielo robbi ariente veron
# kelas :x.2
# no.absen :14

# %%
print("nama: jielo robbi ariente veron")
print("kelas:x.2")
print("no.absen:15")
# Out:
# nama: jielo robbi ariente veron
# kelas:x.2
# no.absen:15

# %%
print ("""nama:jielo robbi ariente veron
kelas:x.2
no.absen:14""")
# Out:
# nama:jielo robbi ariente veron
# kelas:x.2
# no.absen:14

# %%
print ("nama\t\t:jielo robbi ariente veron\nkelas\t\t:x.2\nno.absen\t:14")
# Out:
# nama		:jielo robbi ariente veron
# kelas		:x.2
# no.absen	:14

# %% [markdown]
# Jadwal Pelajaran Mingguan

# %%
print("Jadwal Pelajaran Kelas X.2 - MAN Demak 2025/2026")
print("================================================\n")

print("Jam\tSenin\t\tSelasa\t\tRabu\t\tKamis\t\tJumat\t\tSabtu")

print("JamJam 1\tMat Wajib\tB. Arab\t\tB. Jawa\t\tFisika\t\tMat Wajib\tBiologi")
print("Jam 2\tMat Wajib\tB. Arab\t\tB. Jawa\t\tFisika\t\tMat Wajib\tBiologi")
print("Jam 3\tB. Indo\t\tPJOK\t\tFikih\t\tSejarah\t\tPend. Pancasila\tEkonomi")
print("Jam 4\tB. Indo\t\tPJOK\t\tFikih\t\tSejarah\t\tPend. Pancasila\tEkonomi")
print("Jam 5\tB. Arab\t\tB. Indo\t\tKimia\t\tBiologi\t\tSeni Musik\tSKI")
print("Jam 6\tB. Arab\t\tB. Indo\t\tKimia\t\tGeografi\t-\t\tSKI")
print("Jam 7\tB. Ing\t\tAkidah A.\tSeni Musik\tGeografi\t-\t\tQur\'an Hadist")
print("Jam 8\tB. Ing\t\tAkidah A.\tPKWU\t\tSosiologi\t-\t\tQur\'an Hadist")
print("Jam 9\tB. Ing\t\tBK\t\tPKWU\t\tSosiologi\t-\t\tKKA")
print("Jam 10\t-\t\t-\t\t-\t\t-\t\t-\t\tKKA")
# Out:
# Jadwal Pelajaran Kelas X.2 - MAN Demak 2025/2026
# ================================================
#
# Jam	Senin		Selasa		Rabu		Kamis		Jumat		Sabtu
# JamJam 1	Mat Wajib	B. Arab		B. Jawa		Fisika		Mat Wajib	Biologi
# Jam 2	Mat Wajib	B. Arab		B. Jawa		Fisika		Mat Wajib	Biologi
# Jam 3	B. Indo		PJOK		Fikih		Sejarah		Pend. Pancasila	Ekonomi
# Jam 4	B. Indo		PJOK		Fikih		Sejarah		Pend. Pancasila	Ekonomi
# Jam 5	B. Arab		B. Indo		Kimia		Biologi		Seni Musik	SKI
# Jam 6	B. Arab		B. Indo		Kimia		Geografi	-		SKI
# Jam 7	B. Ing		Akidah A.	Seni Musik	Geografi	-		Qur'an Hadist
# Jam 8	B. Ing		Akidah A.	PKWU		Sosiologi	-		Qur'an Hadist
# Jam 9	B. Ing		BK		PKWU		Sosiologi	-		KKA
# Jam 10	-		-		-		-		-		KKA

# %% [markdown]
# #Parameter Fungsi Print

# %%
nama_siswa_1 = "jielo"
nama_siswa_2 = "Aida"
nama_siswa_3 = "Dani"

print(nama_siswa_1, end ="-")
print(nama_siswa_2, end = "-")
print(nama_siswa_3)
# Out:
# jielo-Aida-Dani

# %%
nama_siswa_1 = "jielo"
nama_siswa_2 = "aida"
nama_siswa_3 = "dani"
nama_siswa_4 = "nurul"

print(nama_siswa_4, end="/")
print(nama_siswa_2, end="/")
print(nama_siswa_1, end="/")
print(nama_siswa_3)
# Out:
# nurul/aida/jielo/dani

# %%
nama_siswa_5 = "hasbi"
nama_siswa_6 = "habibi"
nama_siswa_7 = "rendra"
nama_siswa_8 = "nauval"

print(nama_siswa_5,nama_siswa_8,nama_siswa_7,nama_siswa_6,nama_siswa_8, sep="*")
# Out:
# hasbi*nauval*rendra*habibi*nauval

# %%
print('bu shinta berkata,"Berikut adalah piket harian kelas x.2 yang di simpan di file D:\\MAN Demak\\Jadwal Piket."\nSENIN\tSELAS\tRABU\nJielo\tHasbi\tNaufal\nAzam\tAida\tNurul')
# Out:
# bu shinta berkata,"Berikut adalah piket harian kelas x.2 yang di simpan di file D:\MAN Demak\Jadwal Piket."
# SENIN	SELAS	RABU
# Jielo	Hasbi	Naufal
# Azam	Aida	Nurul
